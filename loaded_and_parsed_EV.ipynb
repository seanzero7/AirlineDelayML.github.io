# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
'''This cell tidys the data so it can be better processed'''

EV = pd.read_csv("/Users/juliabaratta/Desktop/epa_EV.csv")
#removes unnecessary rows
EV = EV.iloc[5:-2]
#drops aggrigated rows to avoid unnecessary columns 
EV = EV.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 18', 'Unnamed: 19' ], axis=1)
#renames columns so they make more sense 
# EPS = electric power sector , CS = commercial sector, IS = industrial sector, RS = residential sector
# utl = utility scale, SS = small scale
column_rename = {"Table 3.21. Net Generation from Solar Photovoltaic": "State", "Unnamed: 8": "EPS:Electric_Utilities_Utl2021", "Unnamed: 9": "EPS:Electric_Utilities_Utl2020", "Unnamed: 10": "EPS:IPP_Utl2021", "Unnamed: 11": "EPS:IPP_Utl2020", "Unnamed: 14": "CS:Utl2021", "Unnamed: 15": "CS:Utl2020", "Unnamed: 16": "CS:SS2021", "Unnamed: 17": "CS:SS2020", "Unnamed: 20": "IS:Utl2021", "Unnamed: 21": "IS:Utl2020", "Unnamed: 22": "IS:SS2021", "Unnamed: 23": "IS:SS2020", "Unnamed: 24": "RS:SS2021", "Unnamed: 25": "RS:SS2020"}
EV = EV.rename(columns=column_rename)
#dros rows that don't match the unit of observation
EV = EV.drop([12, 16, 22, 30, 40, 45, 50, 59, 63])

EV = EV.set_index("State")
#deletes commas 
for column in EV.columns: 
    EV[column] = EV[column].str.replace(',', '', regex=True)
    #EV[column] = EV[column].str.replace('0', np.NaN, regex=True)
#converts to int    
EV['RS:SS2020'] = EV['RS:SS2020'].astype(int)
EV['RS:SS2021'] = EV['RS:SS2021'].astype(int)

EV.head(20)
# Out:
#               EPS:Electric_Utilities_Utl2021 EPS:Electric_Utilities_Utl2020  \
# State
# New England                              144                            156
# Connecticut                                2                              3
# Maine                                      0                              0
# Massachusetts                             86                             92
# New Hampshire                              0                              0
# Rhode Island                               0                              0
# Vermont                                   56                             61
# New Jersey                               115                             77
# New York                                   0                              0
# Pennsylvania                               0                              0
# Illinois                                   2                              2
# Indiana                                  372                            187
# Michigan                                  85                             89
# Ohio                                       8                              7
# Wisconsin                                253                             17
# Iowa                                       9                             10
# Kansas                                     3                              3
# Minnesota                                 33                             19
# Missouri                                  18                             13
# Nebraska                                   8                              8
#
#               EPS:IPP_Utl2021 EPS:IPP_Utl2020 CS:Utl2021 CS:Utl2020 CS:SS2021  \
# State
# New England              2312            1854         10         11      2401
# Connecticut               259             206          3          4       339
# Maine                     158              28          0          0        68
# Massachusetts            1490            1300          7          7      1565
# New Hampshire               4               4          0          0        73
# Rhode Island              284             195          0          0       286
# Vermont                   118             122          0          0        70
# New Jersey               1128            1082        128        139      1245
# New York                 1143             822         10         11      1455
# Pennsylvania              212             128          4          4       210
# Illinois                  511              75          0          2       573
# Indiana                   199             170          2          2       106
# Michigan                  338              65          0          1        79
# Ohio                      658             153          6          2       127
# Wisconsin                 110              73          4          3        81
# Iowa                      216              12          0          0       146
# Kansas                     58              55          0          0        22
# Minnesota                1861            1614          0          0        52
# Missouri                   98              87          0          1       172
# Nebraska                   53              46          0          0         8
#
#               CS:SS2020 IS:Utl2021 IS:Utl2020 IS:SS2021 IS:SS2020  RS:SS2021  \
# State
# New England        2030          5          5       155       145       1742
# Connecticut         275          0          0        46        42        479
# Maine                32          0          0         0         0         67
# Massachusetts      1383          5          5        95        91        873
# New Hampshire        53          0          0        11         9        110
# Rhode Island        220          0          0         1         0         99
# Vermont              66          0          0         2         2        114
# New Jersey         1162          7          8       202       198       1218
# New York           1138          6          7        17        17       1230
# Pennsylvania        191          7          8        69        68        379
# Illinois            241          0          0         2         1        350
# Indiana              88          0          0         8         6        104
# Michigan             67          0          0         4         3        109
# Ohio                127          2          2        33        27        118
# Wisconsin            51          0          0        24        21         76
# Iowa                129          0          0         9         8         91
# Kansas               19          0          0         0         0         38
# Minnesota            44          0          0        21        17        110
# Missouri            158          0          0        10         7        251
# Nebraska              8          0          0         3         1         15
#
#                RS:SS2020
# State
# New England         1602
# Connecticut          418
# Maine                 57
# Massachusetts        847
# New Hampshire         95
# Rhode Island          79
# Vermont              106
# New Jersey          1143
# New York            1136
# Pennsylvania         331
# Illinois             185
# Indiana               73
# Michigan              85
# Ohio                  83
# Wisconsin             58
# Iowa                  73
# Kansas                29
# Minnesota             79
# Missouri             195
# Nebraska              12
