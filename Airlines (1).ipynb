# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# !git clone https://github.com/seanzero7/Sean-and-Julia-Data-Science.git
df = pd.read_csv('Sean-and-Julia-Data-Science/Airline_delays.csv')
# Out:
# Cloning into 'Sean-and-Julia-Data-Science'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 48 (delta 9), reused 4 (delta 4), pack-reused 38
# Receiving objects: 100% (48/48), 609.15 KiB | 4.61 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
df = pd.read_csv('Sean-and-Julia-Data-Science/Airline_delays.csv')
df.columns
# Out:
# Index(['YEAR', 'DAY_OF_WEEK', 'FL_DATE', 'MKT_CARRIER_AIRLINE_ID',
#        'ORIGIN_AIRPORT_ID', 'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID',
#        'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'DEST_CITY_NAME',
#        'DEST_STATE_ABR', 'CRS_DEP_TIME', 'DEP_TIME', 'TAXI_OUT', 'WHEELS_OFF',
#        'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME', 'CANCELLED',
#        'DIVERTED', 'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY'],
#       dtype='object')

# %%
#What origin City has had the most airline delays on the date 1/2/23
df.ORIGIN_CITY_NAME.value_counts().plot(kind='bar')
plt.title('Airline Delays by City for 1/2/23')
plt.xlabel('City')
plt.ylabel('# of Delays')
plt.show()
#Nashville, TN had the most delayed airlines on the date 1/2/23.
